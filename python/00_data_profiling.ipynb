# %%
import pandas as pd

# %%
customers = pd.read_csv("olist_customers_dataset.csv")
geolocation = pd.read_csv("olist_geolocation_dataset.csv")
order_items = pd.read_csv("olist_order_items_dataset.csv")
order_payments = pd.read_csv("olist_order_payments_dataset.csv")
order_reviews = pd.read_csv("olist_order_reviews_dataset.csv")
orders = pd.read_csv("olist_orders_dataset.csv")
products = pd.read_csv("olist_products_dataset.csv")
sellers = pd.read_csv("olist_sellers_dataset.csv")
category_translation = pd.read_csv("product_category_name_translation.csv")

# %%
print("Customers:", customers.shape)
print("Geolocation:", geolocation.shape)
print("Order Items:", order_items.shape)
print("Order Payments:", order_payments.shape)
print("Order Reviews:", order_reviews.shape)
print("Orders:", orders.shape)
print("Products:", products.shape)
print("Sellers:", sellers.shape)
print("Category Translation:", category_translation.shape)
# Out:
# Customers: (99441, 5)
# Geolocation: (1000163, 5)
# Order Items: (112650, 7)
# Order Payments: (103886, 5)
# Order Reviews: (99224, 7)
# Orders: (99441, 8)
# Products: (32951, 9)
# Sellers: (3095, 4)
# Category Translation: (71, 2)

# %%
datasets = {
    "Customers": customers,
    "Geolocation": geolocation,
    "Order Items": order_items,
    "Order Payments": order_payments,
    "Order Reviews": order_reviews,
    "Orders": orders,
    "Products": products,
    "Sellers": sellers,
    "Category Translation": category_translation
}

for name, df in datasets.items():
    print(f"\n--- {name} ---")
    print(df.isnull().sum()[df.isnull().sum() > 0])
# Out:
# --- Customers ---
# Series([], dtype: int64)
#
# --- Geolocation ---
# Series([], dtype: int64)
#
# --- Order Items ---
# Series([], dtype: int64)
#
# --- Order Payments ---
# Series([], dtype: int64)
#
# --- Order Reviews ---
# review_comment_title      87656
# review_comment_message    58247
# dtype: int64
#
# --- Orders ---
# order_approved_at                 160
# order_delivered_carrier_date     1783
# order_delivered_customer_date    2965
# dtype: int64
#
# --- Products ---
# product_category_name         610
# product_name_lenght           610
# product_description_lenght    610
# product_photos_qty            610
# product_weight_g                2
# product_length_cm               2
# product_height_cm               2
# product_width_cm                2
# dtype: int64
#
# --- Sellers ---
# Series([], dtype: int64)
#
# --- Category Translation ---
# Series([], dtype: int64)

# %%
print("Customers:", customers['customer_id'].duplicated().sum())

print("Geolocation:", geolocation[['geolocation_zip_code_prefix',
                                    'geolocation_lat',
                                    'geolocation_lng']].duplicated().sum())

print("Order Items:", order_items[['order_id', 'order_item_id']].duplicated().sum())

print("Order Payments:", order_payments[['order_id', 'payment_sequential']].duplicated().sum())

print("Order Reviews:", order_reviews['review_id'].duplicated().sum())

print("Orders:", orders['order_id'].duplicated().sum())

print("Products:", products['product_id'].duplicated().sum())

print("Sellers:", sellers['seller_id'].duplicated().sum())

print("Category Translation:", category_translation['product_category_name'].duplicated().sum())
# Out:
# Customers: 0
# Geolocation: 280009
# Order Items: 0
# Order Payments: 0
# Order Reviews: 814
# Orders: 0
# Products: 0
# Sellers: 0
# Category Translation: 0

# %%
print("Unique customer_id:", customers['customer_id'].nunique())
print("Unique customer_unique_id:", customers['customer_unique_id'].nunique())
# Out:
# Unique customer_id: 99441
# Unique customer_unique_id: 96096

# %%
print("Unique orders:", orders['order_id'].nunique())
print("Unique customer_id:", orders['customer_id'].nunique())
# Out:
# Unique orders: 99441
# Unique customer_id: 99441

# %%
print("Orders per customer:")
print(orders['customer_id'].value_counts().head(10))
# Out:
# Orders per customer:
# customer_id
# edb027a75a1449115f6b43211ae02a24    1
# 9ef432eb6251297304e76186b10a928d    1
# b0830fb4747a6c6d20dea0b8c802d7ef    1
# 41ce2a54c0b03bf3443c3d931a367089    1
# f88197465ea7920adcdbec7375364d82    1
# 8ab97904e6daea8866dbdbc4fb7aad2c    1
# 503740e9ca751ccdda7ba28e9ab8f608    1
# ed0271e0b7da060a393796590e7b737a    1
# 9bdf08b4b3b52b5526ff42d37d47f222    1
# f54a9f0e6b351c431402b8461ea51999    1
# Name: count, dtype: int64

# %%
print("Unique order_id:", order_items['order_id'].nunique())
print("Unique product_id:", order_items['product_id'].nunique())
print("Unique seller_id:", order_items['seller_id'].nunique())
# Out:
# Unique order_id: 98666
# Unique product_id: 32951
# Unique seller_id: 3095

# %%
print("Unique order_id:", order_payments['order_id'].nunique())
print("Unique payment types:", order_payments['payment_type'].nunique())
# Out:
# Unique order_id: 99440
# Unique payment types: 5

# %%
print(order_payments['payment_type'].unique())
# Out:
# ['credit_card' 'boleto' 'voucher' 'debit_card' 'not_defined']

# %%
print("Unique review_id:", order_reviews['review_id'].nunique())
print("Unique order_id:", order_reviews['order_id'].nunique())
# Out:
# Unique review_id: 98410
# Unique order_id: 98673

# %%
print("Unique product_id:", products['product_id'].nunique())
print("Unique product categories:", products['product_category_name'].nunique())
# Out:
# Unique product_id: 32951
# Unique product categories: 73

# %%
print("Unique seller_id:", sellers['seller_id'].nunique())
print("Unique seller ZIP codes:", sellers['seller_zip_code_prefix'].nunique())
# Out:
# Unique seller_id: 3095
# Unique seller ZIP codes: 2246

# %%
print("Unique ZIP codes:", geolocation['geolocation_zip_code_prefix'].nunique())
print("Unique latitude:", geolocation['geolocation_lat'].nunique())
print("Unique longitude:", geolocation['geolocation_lng'].nunique())
# Out:
# Unique ZIP codes: 19015
# Unique latitude: 717360
# Unique longitude: 717613

# %%
print("Unique Portuguese categories:",
      category_translation['product_category_name'].nunique())

print("Unique English categories:",
      category_translation['product_category_name_english'].nunique())
# Out:
# Unique Portuguese categories: 71
# Unique English categories: 71

# %%
# 5. Date range + monthly breakdown

orders['order_purchase_timestamp'] = pd.to_datetime(
    orders['order_purchase_timestamp']
)

print(
    orders['order_purchase_timestamp'].min(),
    orders['order_purchase_timestamp'].max()
)

print(
    orders.groupby(
        orders['order_purchase_timestamp'].dt.to_period('M')
    ).size()
)
# Out:
# 2016-09-04 21:15:19 2018-10-17 17:30:18
# order_purchase_timestamp
# 2016-09       4
# 2016-10     324
# 2016-12       1
# 2017-01     800
# 2017-02    1780
# 2017-03    2682
# 2017-04    2404
# 2017-05    3700
# 2017-06    3245
# 2017-07    4026
# 2017-08    4331
# 2017-09    4285
# 2017-10    4631
# 2017-11    7544
# 2017-12    5673
# 2018-01    7269
# 2018-02    6728
# 2018-03    7211
# 2018-04    6939
# 2018-05    6873
# 2018-06    6167
# 2018-07    6292
# 2018-08    6512
# 2018-09      16
# 2018-10       4
# Freq: M, dtype: int64

# %%
print(orders['order_status'].value_counts())
# Out:
# order_status
# delivered      96478
# shipped         1107
# canceled         625
# unavailable      609
# invoiced         314
# processing       301
# created            5
# approved           2
# Name: count, dtype: int64

# %%
print(order_payments['payment_type'].value_counts())
# Out:
# payment_type
# credit_card    76795
# boleto         19784
# voucher         5775
# debit_card      1529
# not_defined        3
# Name: count, dtype: int64

# %%
print(order_reviews['review_score'].value_counts().sort_index())
# Out:
# review_score
# 1    11424
# 2     3151
# 3     8179
# 4    19142
# 5    57328
# Name: count, dtype: int64

# %%
print(products['product_category_name'].value_counts().head(20))
# Out:
# product_category_name
# cama_mesa_banho                      3029
# esporte_lazer                        2867
# moveis_decoracao                     2657
# beleza_saude                         2444
# utilidades_domesticas                2335
# automotivo                           1900
# informatica_acessorios               1639
# brinquedos                           1411
# relogios_presentes                   1329
# telefonia                            1134
# bebes                                 919
# perfumaria                            868
# papelaria                             849
# fashion_bolsas_e_acessorios           849
# cool_stuff                            789
# ferramentas_jardim                    753
# pet_shop                              719
# eletronicos                           517
# construcao_ferramentas_construcao     400
# eletrodomesticos                      370
# Name: count, dtype: int64

# %%
print(customers['customer_state'].value_counts())
# Out:
# customer_state
# SP    41746
# RJ    12852
# MG    11635
# RS     5466
# PR     5045
# SC     3637
# BA     3380
# DF     2140
# ES     2033
# GO     2020
# PE     1652
# CE     1336
# PA      975
# MT      907
# MA      747
# MS      715
# PB      536
# PI      495
# RN      485
# AL      413
# SE      350
# TO      280
# RO      253
# AM      148
# AC       81
# AP       68
# RR       46
# Name: count, dtype: int64

# %%
print(sellers['seller_state'].value_counts())
# Out:
# seller_state
# SP    1849
# PR     349
# MG     244
# SC     190
# RJ     171
# RS     129
# GO      40
# DF      30
# ES      23
# BA      19
# CE      13
# PE       9
# PB       6
# MS       5
# RN       5
# MT       4
# RO       2
# SE       2
# AC       1
# PI       1
# MA       1
# AM       1
# PA       1
# Name: count, dtype: int64
